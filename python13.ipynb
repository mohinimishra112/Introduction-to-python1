# %%
def add_two():
    a = 10
    b = 20
    c = a+b
    print(c)

# %%
add_two()
# Out:
# 30

# %%
add_two()
# Out:
# 30

# %%
if 3>2:
    print("greater")
# Out:
# greater

# %%
def greet():
    name = input("enter your name")
    print(f"hello {name} welcome to the party")
greet()
# Out:
# enter your name mohini
# hello mohini welcome to the party

# %%
def greet_user():
    name = input("Please enter your name: ")
    print(f"Hello, {name}! Nice to meet you.")

# %%
greet_user()
# Out:
# Please enter your name:  mohini
# Hello, mohini! Nice to meet you.

# %%
greet_user()
# Out:
# Please enter your name:  mohini
# Hello, mohini! Nice to meet you.
