# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
multiplication = num1 * num2
addition = num1 + num2
print(f"Multiplication of {num1} and {num2} is: {multiplication}")
print(f"Sum of {num1} and {num2} is: {addition}")
# Out:
# Enter first number:  5
# Enter second number:  7
# Multiplication of 5.0 and 7.0 is: 35.0
# Sum of 5.0 and 7.0 is: 12.0

# %%
a = 10
b = 20
largest = a if a > b else b
print(f"The largest number is: {largest}")
# Out:
# The largest number is: 20

# %%
name = input("Enter your name: ")
age = input("Enter your age: ")
city = input("Enter your city: ")
print(f"Hello, my name is {name}. I am {age} years old and I live in {city}.")
# Out:
# Enter your name:  mohini
# Enter your age:  20
# Enter your city:  bangalore
# Hello, my name is mohini. I am 20 years old and I live in bangalore.

# %%
import math
a = float(input("Enter side a: "))
b = float(input("Enter side b: "))
c = float(input("Enter side c: "))
s = (a + b + c) / 2
area = math.sqrt(s * (s - a) * (s - b) * (s - c))
print(f"The area of the triangle is: {area:.2f}")
# Out:
# Enter side a:  4
# Enter side b:  6
# Enter side c:  7
# The area of the triangle is: 11.98
